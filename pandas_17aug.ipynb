# %%
import numpy as np
import pandas as pd

# %%
# "C:\\Users\\Mayuri\\data.csv"
# r"C:\Users\Mayuri\data.csv"
# "C:/Users/Mayuri/data.csv"

# %%
import pandas as pd

df = pd.DataFrame({
    "Product": ["Laptop", "Mouse", "Keyboard", "Monitor", "Printer"],
    "Sales": [50000, 1500, 2500, 12000, 8000],
    "Quantity": [2, 5, 3, 2, 1]
})

print(df)
# Out:
#     Product  Sales  Quantity
# 0    Laptop  50000         2
# 1     Mouse   1500         5
# 2  Keyboard   2500         3
# 3   Monitor  12000         2
# 4   Printer   8000         1

# %%
df = pd.DataFrame({
    "Product": ["Laptop", "Mouse", "Keyboard", "Monitor"],
    "Sales": [50000, 1500, 2500, 12000]
}, index=[101, 102, 103, 104])

print(df)


# loc[] looks at the index label    df.loc[101]
# iloc[] looks at the position      df.iloc[101]
# Out:
#       Product  Sales
# 101    Laptop  50000
# 102     Mouse   1500
# 103  Keyboard   2500
# 104   Monitor  12000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 11
#       6 print(df)
#       9 df.loc[101]
# ---> 11 df.iloc[101]
#      13 # loc[] looks at the index label    df.loc[101]
#      14 # iloc[] looks at the position      df.iloc[101]
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "Product": ["Laptop", "Mouse", "Keyboard", "Monitor", "Printer"],
    "Sales": [50000, 1500, 2500, 12000, 8000],
    "Quantity": [2, 5, 3, 2, 1]
}, index=[101, 102, 103, 104, 105])

print(df)

# %%
import pandas as pd

df = pd.DataFrame({
    "Product": ["Laptop", "Notebook", "Book", "Mouse", "Book Stand", "Keyboard"],
    "City": ["Jaipur", "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune"],
    "Sales": [50000, 8000, 6000, 3000, 12000, 15000],
    "Rating": [4.5, 4.0, 4.2, 3.8, 4.5, 4.1]
}, index=[101, 102, 103, 104, 105, 106])


# print(df)
# print(df.loc[0])
# print(df.iloc[0])


# print(df.columns)


# df1 = df[df['Sales'] > 8000]
# print(df1)


# print(df[df['City'] == 'Delhi'])


# df[(df['Sales'] > 10000) & (df['Rating'] >= 4)]


# df[(df['Category'] == 'Electronics') | (df['Category'] == 'Books')]


# df[df['City'].isin(['Jaipur', 'Delhi'])]


# df[df['Sales'].between(5000, 20000)]


# df[df['Product'].str.contains('Book', case=False, na=False)]


# df.query("Sales > 10000 and Rating >= 4")
# Out:
# Product    Laptop
# City       Jaipur
# Sales       50000
# Rating        4.5
# Name: 101, dtype: object

# %%
import pandas as pd

df = pd.DataFrame({
    "Employee": [
        "Aman", "Riya", "Neha", "Rahul", "Priya",
        "Karan", "Sneha", "Vikas", "Anjali", "Mohit"
    ],
    "City": [
        "Jaipur", "Delhi", "Mumbai", "Jaipur", "Pune",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune"
    ],
    "Department": [
        "IT", "HR", "Finance", "IT", "Sales",
        "Finance", "IT", "HR", "Sales", "IT"
    ],
    "Salary": [
        55000, 45000, 60000, 72000, 40000,
        65000, 58000, 42000, 48000, 75000
    ],
    "Experience": [
        3, 2, 5, 6, 1,
        4, 3, 2, 3, 7
    ],
    "Rating": [
        4.5, 3.8, 4.2, 4.7, 3.5,
        4.1, 4.4, 3.9, 4.0, 4.8
    ]
})



print(df)





# Code                                                       | Meaning                                    |
# ---------------------------------------------------------- | ------------------------------------------ |
# df.sort_values('Sales')                                    | Sales low → high                           |
# df.sort_values('Sales', ascending=False)                   | Sales high → low                           |
# df.sort_values(['Category','Sales'], ascending=[True,False])| Category A→Z, then Sales high→low          |
# df.nlargest(5,'Sales')                                      | Top 5 Sales                                |
# df.nsmallest(5,'Sales')                                     | Bottom 5 Sales                             |
# df['Sales'].rank(ascending=False)                           | Highest Sales gets Rank 1                  |
# method='dense'                                       | Ties get same rank, next rank doesn't skip |
# Out:
#   Employee    City Department  Salary  Experience  Rating
# 0     Aman  Jaipur         IT   55000           3     4.5
# 1     Riya   Delhi         HR   45000           2     3.8
# 2     Neha  Mumbai    Finance   60000           5     4.2
# 3    Rahul  Jaipur         IT   72000           6     4.7
# 4    Priya    Pune      Sales   40000           1     3.5
# 5    Karan   Delhi    Finance   65000           4     4.1
# 6    Sneha  Mumbai         IT   58000           3     4.4
# 7    Vikas  Jaipur         HR   42000           2     3.9
# 8   Anjali   Delhi      Sales   48000           3     4.0
# 9    Mohit    Pune         IT   75000           7     4.8

# %%
import pandas as pd

df = pd.DataFrame({
    "Order_ID": range(1001, 1051),

    "Product": [
        "Laptop", "Mouse", "Keyboard", "Notebook", "Monitor",
        "Book Stand", "Headphones", "Printer", "Tablet", "Pen Drive",
        "Laptop Bag", "Book", "Webcam", "Chair", "Desk",
        "Notebook", "Mouse Pad", "Keyboard", "Laptop", "Monitor",
        "Book Shelf", "Headphones", "Printer", "Tablet", "Pen",
        "Laptop Bag", "Book", "Webcam", "Chair", "Desk",
        "Keyboard", "Mouse", "Laptop", "Notebook", "Monitor",
        "Book Stand", "Printer", "Headphones", "Tablet", "Pen Drive",
        "Laptop", "Book", "Webcam", "Chair", "Desk",
        "Mouse Pad", "Keyboard", "Monitor", "Notebook", "Laptop"
    ],

    "Category": [
        "Electronics", "Accessories", "Accessories", "Books", "Electronics",
        "Books", "Electronics", "Electronics", "Electronics", "Accessories",
        "Accessories", "Books", "Electronics", "Furniture", "Furniture",
        "Books", "Accessories", "Accessories", "Electronics", "Electronics",
        "Books", "Electronics", "Electronics", "Electronics", "Accessories",
        "Accessories", "Books", "Electronics", "Furniture", "Furniture",
        "Accessories", "Accessories", "Electronics", "Books", "Electronics",
        "Books", "Electronics", "Electronics", "Electronics", "Accessories",
        "Electronics", "Books", "Electronics", "Furniture", "Furniture",
        "Accessories", "Accessories", "Electronics", "Books", "Electronics"
    ],

    "City": [
        "Jaipur", "Delhi", "Mumbai", "Pune", "Jaipur",
        "Delhi", "Mumbai", "Kolkata", "Pune", "Jaipur",
        "Delhi", "Mumbai", "Pune", "Jaipur", "Delhi",
        "Kolkata", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Kolkata", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Kolkata", "Pune",
        "Jaipur", "Delhi", "Mumbai", "Pune", "Kolkata",
        "Jaipur", "Delhi", "Mumbai", "Pune", "Kolkata",
        "Delhi", "Mumbai", "Jaipur", "Pune", "Kolkata",
        "Jaipur", "Delhi", "Mumbai", "Pune", "Jaipur"
    ],

    "Sales": [
        55000, 2500, 4500, 1800, 32000,
        6500, 8500, 22000, 28000, 4000,
        7500, 3500, 9500, 15000, 12000,
        2500, 1800, 5000, 48000, 27000,
        7000, 9000, 21000, 26000, 1200,
        6500, 3200, 11000, 14500, 13000,
        5200, 2800, 60000, 2200, 30000,
        5500, 19500, 10500, 24000, 3500,
        45000, 4000, 12500, 16000, 14000,
        3000, 4800, 29000, 2000, 68000
    ],

    "Quantity": [
        5, 10, 8, 15, 4,
        6, 7, 3, 5, 9,
        6, 12, 7, 3, 4,
        5, 10, 8, 6, 4,
        7, 6, 3, 5, 15,
        8, 10, 6, 4, 5,
        8, 12, 5, 14, 4,
        9, 3, 5, 7, 10,
        4, 8, 5, 3, 6,
        11, 7, 4, 12, 6
    ],

    "Rating": [
        4.5, 4.0, 3.8, 4.2, 4.7,
        4.1, 4.3, 3.9, 4.6, 3.7,
        4.2, 4.0, 4.4, 4.5, 3.8,
        4.1, 3.9, 4.0, 4.8, 4.5,
        4.2, 4.1, 3.8, 4.6, 3.5,
        4.0, 4.3, 4.5, 3.9, 4.1,
        4.0, 3.8, 4.9, 4.2, 4.7,
        4.1, 3.9, 4.4, 4.6, 3.7,
        4.8, 4.0, 4.3, 4.5, 4.1,
        3.9, 4.2, 4.7, 4.0, 4.9
    ],

    "Payment_Mode": [
        "UPI", "Cash", "Card", "UPI", "Card",
        "Cash", "UPI", "Card", "UPI", "Cash",
        "Card", "UPI", "Cash", "Card", "UPI",
        "Cash", "Card", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash"
    ]
})

print(df)


# 1.
# df[df["Sales"] > 10000]


# 2.
# df[df["City"] == "Jaipur"]


# 3.
# df[df["Rating"] >= 4.5]


# 4.
# df[df["Category"] == "Electronics"]


# 5.
# df[(df["Sales"] > 10000) & (df["Rating"] >= 4)]


# 6.
# df[(df["Sales"] > 20000) & (df["Quantity"] >= 5)]


# 7.
# df[(df["Category"] == "Electronics") & (df["Sales"] > 15000)]


# 8.
# df[(df["City"] == "Jaipur") & (df["Rating"] >= 4.5)]


# 9.
# df[(df["Category"] == "Electronics") | (df["Category"] == "Books")]


# 10.
# df[(df["City"] == "Jaipur") | (df["City"] == "Delhi")]


# 11.
# df[(df["Payment_Mode"] == "UPI") | (df["Payment_Mode"] == "Card")]


# 12.
# df[(df["Category"] == "Books") | (df["Category"] == "Furniture")]


# 13.
# df[df["City"].isin(["Jaipur", "Delhi", "Mumbai"])]


# 14.
# df[df["Category"].isin(["Electronics", "Books", "Accessories"])]


# 15.
# df[df["Payment_Mode"].isin(["UPI", "Card"])]


# 16.
# df[df["City"].isin(["Pune", "Kolkata", "Jaipur"])]


# 17.
# df[df["Sales"].between(5000, 20000)]


# 18.
# df[df["Quantity"].between(5, 10)]


# 19.
# df[df["Rating"].between(4.0, 4.5)]


# 20.
# df[df["Sales"].between(10000, 30000)]


# 21.
# df[df["Product"].str.contains("Book", na=False)]


# 22.
# df[df["Product"].str.contains("Laptop", case=False, na=False)]


# 23.
# df[df["Product"].str.contains("Mouse", case=False, na=False)]


# 24.
# df[df["Product"].str.contains("Pen", case=False, na=False)]


# 25.
# df.query("Sales > 10000 and Rating >= 4")


# 26.
# df.query("Quantity >= 5 and Sales > 15000")


# 27.
# df.query("Rating >= 4.5 and Sales > 20000")


# 28.
# df.query("Quantity > 5 and Rating >= 4.2")


# 29.
# df[
#     df["City"].isin(["Jaipur", "Delhi"]) &
#     (df["Sales"] > 10000)
# ]


# 30.
# df[
#     df["Category"].isin(["Electronics", "Books"]) &
#     (df["Rating"] >= 4)
# ]


# 31.
# df[
#     df["Sales"].between(5000, 20000) &
#     (df["Quantity"] >= 5)
# ]


# 32.
# df[
#     df["City"].isin(["Mumbai", "Pune"]) &
#     (df["Sales"] > 10000) &
#     (df["Rating"] >= 4)
# ]


# 33.
# df.loc[
#     df["Sales"] > 20000,
#     ["Product", "City", "Sales"]
# ]


# 34.
# df.loc[
#     df["Rating"] >= 4.5,
#     ["Product", "Rating"]
# ]


# 35.
# df.loc[
#     df["City"] == "Jaipur",
#     ["Order_ID", "Product", "Sales"]
# ]


# 36.
# df.loc[
#     df["Category"].isin(["Electronics", "Books"]),
#     ["Product", "Category", "Sales"]
# ]


# 37.
# df[
#     (df["Sales"] > 10000) &
#     (df["Rating"] >= 4.5) &
#     (df["City"].isin(["Jaipur", "Delhi"]))
# ]


# 38.
# df[
#     df["Category"].isin(["Electronics", "Books"]) &
#     df["Sales"].between(5000, 30000) &
#     (df["Rating"] >= 4)
# ]


# 39.
# df[
#     df["Product"].str.contains(
#         "Book|Laptop",
#         case=False,
#         na=False
#     )
# ]


# 40.
# df.loc[
#     (df["Sales"] > 15000) &
#     (df["Quantity"] >= 5) &
#     (df["Rating"] >= 4.2),
#     ["Product", "City", "Sales", "Rating"]
# ]
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories    Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 9       1010   Pen Drive  Accessories   Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "Employee": ["Aman", "Riya", "Neha", "Rahul", "Priya", "Karan", "Sneha", "Vikas"],
    "City": ["Jaipur", "Delhi", "Mumbai", "Jaipur", "Pune", "Delhi", "Mumbai", "Kota"],
    "Department": ["Sales", "HR", "IT", "Finance", "Sales", "IT", "HR", "Finance"],
    "Salary": [35000, 42000, 50000, 38000, 45000, 55000, 40000, 36000],
    "Experience": [2, 4, 5, 3, 4, 6, 3, 2],
    "Performance": [78, 85, 92, 74, 88, 95, 81, 76]
})

df.index = ["E101", "E102", "E103", "E104", "E105", "E106", "E107", "E108"]

print(df)
# Out:
#      Employee    City Department  Salary  Experience  Performance
# E101     Aman  Jaipur      Sales   35000           2           78
# E102     Riya   Delhi         HR   42000           4           85
# E103     Neha  Mumbai         IT   50000           5           92
# E104    Rahul  Jaipur    Finance   38000           3           74
# E105    Priya    Pune      Sales   45000           4           88
# E106    Karan   Delhi         IT   55000           6           95
# E107    Sneha  Mumbai         HR   40000           3           81
# E108    Vikas    Kota    Finance   36000           2           76

# %%
# Select the row with index E103.
# print(df.loc["E103"])
# Select the row with index E106.
# Select the Employee value from index E102.
# Select the Salary of employee E105.
# Select Employee and City for index E104.
# Out:
# 'Riya'
