# %%
class Student:
    pass

stud1 = Student()

# %%
class Car:
    brand = "Kia"
    color = "Black"

car1 = Car()
print(car1.brand)
# Out:
# Kia

# %%
car2 = Car()
car2.brand = "BMW"
print(car2.brand)
# Out:
# BMW

# %%
car3 = Car()
print(car3.brand)
# Out:
# Kia

# %%
Car.brand = "Toyota"
print(car3.brand)
# Out:
# Toyota

# %%
print(car1.brand)
# Out:
# Toyota

# %%
car4 = Car()
print(car4.brand)
# Out:
# Toyota

# %%
# Class :- blueprint/template

# Object :- product

# attributes :- properties

# methods :- actions/behaviour

# %%
stud1 = ["Rohit", "SQL"]          # name, course_name 
print(stud1)


stud2 = ["Ritika", "Python"]
print(stud2)


print(f"{stud1[0]} is in {stud1[1]} course")
# Out:
# ['Rohit', 'SQL']
# ['Ritika', 'Python']
# Rohit is in SQL course

# %%
# code reusability
# easier maintenance
# flexibility :- easier to modify features in the existing code

# %%
class Student:
    pass

stud1 = Student()
print(stud1)

# %%
class Student:
    name = "Radhey"
    degree = "btech"

stud1 = Student()
print(stud1.name, stud1.degree)   

stud2 = Student()
print(stud2.name)
# Out:
# Radhey btech
# Radhey

# %%
class Student:                             #class
    def __init__(self, name, degree):      #__init__ (method) :- constructor (value initialize)
        self.name = name                   #attribute
        self.degree = degree

stud1 = Student("Radhey", "btech")        
print(stud1.name, stud1.degree)

stud2 = Student("Mayuri", "data analytics")
print(stud2.name, stud2.degree)


# self helps us to create connection btw class and object
# Out:
# Radhey btech
# Mayuri data analytics

# %%
class Student:                             
    def __init__(self, name, degree):      
        self.name = name                   
        self.degree = degree

    def stud_info(self):
        print(f"{self.name} is in {self.degree}")    

stud1 = Student("Radhey", "btech")
stud1.stud_info()

stud2 = Student("Rohit", "BCA")
stud2.stud_info()
# Out:
# Radhey is in btech
# Rohit is in BCA

# %%
class Student:                             
    def __init__(self, name, degree, grade, percentage):      
        self.name = name                   
        self.degree = degree
        self.grade = grade
        self.percentage = percentage 

    def stud_info(self):
        print(f"{self.name} is in {self.degree} who got {self.grade} with {self.percentage}%")    

stud1 = Student("Radhey", "btech", "A",92)
stud1.stud_info()

stud2 = Student("Rohit", "BCA", "A",89)
stud2.stud_info()
# Out:
# Radhey is in btech who got A with 92%
# Rohit is in BCA who got A with 89%

# %%
class Student:                             
    def __init__(self, name, degree, grade, percentage):      
        self.name = name                   
        self.degree = degree
        self.grade = grade
        self.percentage = percentage 

    def stud_info(self):
        print(f"{self.name} is in {self.degree} who got {self.grade} with {self.percentage}%")    

stud1 = Student("Radhey", "btech", "A",92)
stud1.stud_info()

# stud2 = Student("Rohit", "BCA", "A",89)
# stud2.stud_info()

stud1.grade = "B"
stud1.percentage = 70
stud1.stud_info()
# Out:
# Radhey is in btech who got A with 92%
# Radhey is in btech who got B with 70%

# %%
class Student:                             
    def __init__(self, name, degree, grade, percentage):      
        self.name = name                   
        self.degree = degree
        self.grade = grade
        self.percentage = percentage 

    def stud_info(self):
        print(f"{self.name} is in {self.degree} who got {self.grade} with {self.percentage}%")    

stud1 = Student("Radhey", "btech", "A",92)
# stud1.stud_info()

del stud1
stud1.stud_info()


# stud2 = Student("Rohit", "BCA", "A",89)
# stud2.stud_info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 15
#      12 # stud1.stud_info()
#      14 del stud1
# ---> 15 stud1.stud_info()
#      18 # stud2 = Student("Rohit", "BCA", "A",89)
#      19 # stud2.stud_info()
#
# NameError: name 'stud1' is not defined

# %%
# Encapsulation :- restrict access to certain attributes and methods to protect data and 
#                  enforce controlled access.

class Student:                             
    def __init__(self, name, degree, grade, percentage):      
        self.name = name                   
        self.degree = degree
        self.grade = grade
        self.__percentage = percentage     


    def stud_info(self):
            print(f"{self.name} is in {self.degree} who got {self.grade} with {(self.__percentage)}%")    


s1 = Student("Radhey", "btech", "A",70)
# s1.stud_info()

print(s1.percentage)

# print(stud1.grade)
# print(stud1.__percentage)
# stud2 = Student("Rohit", "BCA", "A",92)
# stud2.stud_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 19
#      16 s1 = Student("Radhey", "btech", "A",70)
#      17 # s1.stud_info()
# ---> 19 print(s1.percentage)
#      21 # print(stud1.grade)
#      22 # print(stud1.__percentage)
#      23 # stud2 = Student("Rohit", "BCA", "A",92)
#      24 # stud2.stud_info()
#
# AttributeError: 'Student' object has no attribute 'percentage'

# %%
def get_percentage(self):
    return self.__percentage

# %%
class Student:                             
    def __init__(self, name, degree, grade, percentage):      
        self.name = name                   
        self.degree = degree
        self.grade = grade
        self.__percentage = percentage 

    def get_percentage(self):
        return self.__percentage
 
    def stud_info(self):
        print(f"{self.name} is in {self.degree} who got {self.grade} with {self.get_percentage()}%")    

stud1 = Student("Radhey", "btech", "A",89)
# stud1.stud_info()


stud1.get_percentage()
# Out:
# 89

# %%
# Inheritance :- inherits the property from the parent class

class Father:
    def show(self):
        print("I have 100cr. property")

class Child(Father):               # child class(parent class)
    pass

f = Father()
f.show()

c = Child()
c.show()
# Out:
# I have 100cr. property
# I have 100cr. property

# %%
class Father:
    def show(self):
        print("I have 100cr. property")

class Child(Father):
    def game(self, name):
        return name

f = Father()
f.show()
# f.game("Cricket")

c = Child()
# c.show()
# c.game("Football")
# Out:
# I have 100cr. property
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 11
#       9 f = Father()
#      10 f.show()
# ---> 11 f.game("Cricket")
#      13 c = Child()
#      14 # c.show()
#      15 # c.game("Football")
#
# AttributeError: 'Father' object has no attribute 'game'

# %%
# Multiple Inheritance

class Father:
    def skills(self):
        print("Good in driving")


class Mother:
    def talent(self):
        print("Good in interior designing")


class Child(Father, Mother):
    pass

# m = Mother()
# m.skills()


c = Child()

c.skills()
c.talent()
# Out:
# Good in driving
# Good in interior designing

# %%
# Multi-level Inheritance

class Grandfather:
    def eat(self):
        print("Bajre ki roti")


class Father(Grandfather):
    def transport(self):
        print("Cycle")


class Son(Father):
    def talent(self):
        print("Enjoying life")


s = Son()

s.eat()
s.transport()
s.talent()
# Out:
# Bajre ki roti
# Cycle
# Enjoying life

# %%
# Abstract class → class containing abstract methods
# Abstract method → method whose implementation is defined by the child class

# We can't create an object of an abstract class

# %%
from abc import ABC, abstractmethod

class Payment(ABC):

    @abstractmethod
    def pay(self, amount):
        pass


class UPI(Payment):

    def pay(self, amount):
        print("Paid", amount, "using UPI")


class CreditCard(Payment):

    def pay(self, amount):
        print("Paid", amount, "using Credit Card")


p1 = UPI()
p1.pay(500)

p2 = CreditCard()
p2.pay(1000)
# Out:
# Paid 500 using UPI
# Paid 1000 using Credit Card

# %%
class Animal:

    def sound(self):
        print("Animal makes a sound")


class Dog(Animal):

    def sound(self):
        print("Dog barks")


class Cat(Animal):

    def sound(self):
        print("Cat meows")


dog = Dog()
cat = Cat()

dog.sound()
cat.sound()
# Out:
# Dog barks
# Cat meows

# %%
class Senior:
    def talent(Self):
        print("Coding")

class Junior(Senior):
    def talent(self):
        print("singing")

class Lower(Senior):
    def talent(self):
        print("dancing")

j = Junior()
j.talent()

l = Lower()
l.talent()
# Out:
# singing
# dancing
