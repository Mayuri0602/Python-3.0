# %%
# KDE plot (smoothen density curve)

# Kernel Density Estimation
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
plt.figure(figsize=(5, 3))
sns.kdeplot(data = tips, x = 'total_bill')
plt.grid(True)
plt.show()

# %%
iris = sns.load_dataset('iris')
plt.figure(figsize=(5, 3))
sns.kdeplot(data = iris)
plt.grid(True)
plt.show()

# %%
sns.kdeplot(data = tips, x = 'total_bill', hue = 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Violin Plot
# combines the idea of a boxplot and a density plot(kde)
# but also where the data is more concentrated
titanic = sns.load_dataset('titanic')
df = sns.load_dataset('titanic')
plt.figure(figsize=(5,3))
sns.violinplot(x=df['age'])
plt.show()

# %%
import pandas as pd
pd.read_csv('train.csv')

# %%
# Heatmap
# used for the correlation or matrix-like data  (numerical columns)
corr = df.select_dtypes(include='int').corr()
sns.heatmap(corr, vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %%
corr = df[['survived', 'pclass', 'parch', 'sibsp']].corr()
sns.heatmap(corr, vmax=1, vmin=-1, annot=True)
# Out:
# <Axes: >

# %%
# +ve numbers give the direct correlation between the columns(features)
# -ve numbers give the indirect correlation
# 0 --> neutrality
